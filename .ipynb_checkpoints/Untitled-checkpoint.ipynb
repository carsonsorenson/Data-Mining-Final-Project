# %%
import pandas as pd

train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
print("Training Data:")
print("Shape - {}".format(train_data.shape))
print("Columns - {}".format(train_data.columns))
print("Memory Usage - {:.2f} MB".format(train_data.memory_usage().sum() / 1024**2))

print("\nTesting Data:")
print("Shape - {}".format(test_data.shape))
print("Columns - {}".format(test_data.columns))
print("Memory Usage - {:.2f} MB".format(test_data.memory_usage().sum() / 1024**2))
# Out:
# Training Data:
# Shape - (7613, 5)
# Columns - Index(['id', 'keyword', 'location', 'text', 'target'], dtype='object')
# Memory Usage - 0.29 MB
#
# Testing Data:
# Shape - (3263, 4)
# Columns - Index(['id', 'keyword', 'location', 'text'], dtype='object')
# Memory Usage - 0.10 MB

# %%
train_data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test_data.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
print("Distinct keywords for test data: {}".format(test_data.keyword.drop_duplicates().count()))
print("Distinct keywords for train data: {}".format(train_data.keyword.drop_duplicates().count()))
# Out:
# Distinct keywords for test data: 221
# Distinct keywords for train data: 221

# %%
# Find count of words that are in both 
keywords = []
for word in test_data.keyword.drop_duplicates():
    keywords.append(word)
for word in train_data.keyword.drop_duplicates():
    if word not in keywords:
        keywords.append(word)

print("Count of words in training data that aren't in test data: {}".format(len(keywords) - test_data.keyword.drop_duplicates().count()))
# Out:
# Count of words in training data that aren't in test data: 1

# %% [markdown]
# Both datasets have the same number of keywords. There is one keyword in the training dataset that isn't in the testing dataset.

# %%
train_data.target.value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(30,10))
plt.title("Train Data: target", fontsize=20)
train_data.target.value_counts().plot(kind="pie",
                                    labels=["Real", "Fake"],
                                    wedgeprops=dict(width=.7),
                                    autopct="%1.0f%%",
                                    startangle=-20,
                                    textprops={"fontsize": 15})

# %% [markdown]
# There are a few more real examples tan there are fake ones, it's good that it's a fairly even split, it will be good to have plenty of both instances to work with.
#
# Now it's time to preprocess the data.

# %%
train_data.text.head()
# Out:
# 0    Our Deeds are the Reason of this #earthquake M...
# 1               Forest fire near La Ronge Sask. Canada
# 2    All residents asked to 'shelter in place' are ...
# 3    13,000 people receive #wildfires evacuation or...
# 4    Just got sent this photo from Ruby #Alaska as ...
# Name: text, dtype: object

# %%
# !pip install nltk==3.5
import nltk; nltk.download("stopwords")
# !pip install textblob==0.15.3
# !python -m textblob.download_corpora

def preprocessing_data(data):
    # Change all text to lowercase
    data.text = data.text.apply(lambda x: " ".join(x.lower() for x in x.split()))
    
    # Remove punctuation 
    data.text = data.text.str.replace("[^\w\s]","")

    # Remove stopwords
    from nltk.corpus import stopwords
    stop = stopwords.words("english")
    data.text = data.text.apply(lambda x: " ".join(x for x in x.split() if x not in stop))

    # Lemmatize words
    from textblob import Word
    data.text = data.text.apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

    # Remove words with length below 3
    data.text = data.text.apply(lambda x: " ".join(x for x in x.split() if len(x) > 2))

    # Remove rare words
    freq = pd.Series(" ".join(data).split()).value_counts()[-10:]
    freq = list(freq.index)
    data.text = data.text.apply(lambda x: " ".join(x for x in x.split() if x not in freq))

    # Remove common words
    freq = pd.Series(" ".join(data).split()).value_counts()[:10]
    freq = list(freq.index) 
    data.text = data.text.apply(lambda x: " ".join(x for x in x.split() if x not in freq))

    return data
# Out:
# Requirement already satisfied: nltk==3.5 in c:\users\danrl\anaconda3\lib\site-packages (3.5)
# Requirement already satisfied: tqdm in c:\users\danrl\anaconda3\lib\site-packages (from nltk==3.5) (4.43.0)
# Requirement already satisfied: click in c:\users\danrl\anaconda3\lib\site-packages (from nltk==3.5) (7.1.1)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: joblib in c:\users\danrl\anaconda3\lib\site-packages (from nltk==3.5) (0.14.1)
# Requirement already satisfied: regex in c:\users\danrl\anaconda3\lib\site-packages (from nltk==3.5) (2020.11.13)
# Requirement already satisfied: textblob==0.15.3 in c:\users\danrl\anaconda3\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\users\danrl\anaconda3\lib\site-packages (from textblob==0.15.3) (3.5)
# Requirement already satisfied: regex in c:\users\danrl\anaconda3\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (2020.11.13)
# Requirement already satisfied: joblib in c:\users\danrl\anaconda3\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (0.14.1)
# Requirement already satisfied: tqdm in c:\users\danrl\anaconda3\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (4.43.0)
# Requirement already satisfied: click in c:\users\danrl\anaconda3\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (7.1.1)
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\danrl\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
train_data = preprocessing_data(train_data)
test_data = preprocessing_data(test_data)

# %%
train_data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN           deed reason earthquake may allah forgive
# 1   4     NaN      NaN                 forest fire near ronge sask canada
# 2   5     NaN      NaN  resident asked shelter place notified officer ...
# 3   6     NaN      NaN  13000 people receive wildfire evacuation order...
# 4   7     NaN      NaN  got sent photo ruby alaska smoke wildfire pour...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test_data.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                        happened terrible car crash
# 1   2     NaN      NaN  heard earthquake different city stay safe ever...
# 2   3     NaN      NaN  forest fire spot pond goose fleeing across str...
# 3   9     NaN      NaN               apocalypse lighting spokane wildfire
# 4  11     NaN      NaN                 typhoon soudelor kill china taiwan

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# X_train, X_test, y_train, y_test = train_test_split(train_data.text, train_data.target, test_size=0.2, random_state=47)
X_train = train_data["text"]
y_train = train_data["target"]
X_test = test_data["text"]

# vectorizer = TfidfVectorizer()
# X_train = vectorizer.fit_transform(X_train)

# %%
X_test.head()
# Out:
# 0                          happened terrible car crash
# 1    heard earthquake different city stay safe ever...
# 2    forest fire spot pond goose fleeing across str...
# 3                 apocalypse lighting spokane wildfire
# 4                   typhoon soudelor kill china taiwan
# Name: text, dtype: object

# %%
X_train.head()
# Out:
# 0             deed reason earthquake may allah forgive
# 1                   forest fire near ronge sask canada
# 2    resident asked shelter place notified officer ...
# 3    13000 people receive wildfire evacuation order...
# 4    got sent photo ruby alaska smoke wildfire pour...
# Name: text, dtype: object

# %%
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.fit_transform(X_test)

# %%
vectorizer.get_feature_names()
# Out:
# ['001116',
#  '010242',
#  '010401',
#  '015',
#  '0327',
#  '05082015',
#  '0518',
#  '05th',
#  '0600',
#  '07222015',
#  '0800',
#  '0802pm',
#  '0939pm',
#  '100',
#  '1000',
#  '10000',
#  '101',
#  '1019',
#  '103',
#  '1030',
#  '1030pm',
#  '1035',
#  '1040pm',
#  '104527jst',
#  '105',
#  '10km',
#  '10monthold',
#  '10pm',
#  '10th',
#  '10x',
#  '10yearold',
#  '1100',
#  '11000',
#  '1115',
#  '11211',
#  '1138am',
#  '1154am',
#  '1157am',
#  '1179',
#  '118',
#  '119',
#  '11th',
#  '11yearold',
#  '120',
#  '12000',
#  '120v',
#  '1233newcastle',
#  '1245z',
#  '126',
#  '12beyonce',
#  '12k',
#  '130',
#  '13000',
#  '133',
#  '1346',
#  '140000',
#  '140km',
#  '148',
#  '14th',
#  '150',
#  '1500',
#  '150401',
#  '150squarefoot',
#  '157',
#  '1580992',
#  '1581028',
#  '15day',
#  '15km',
#  '15l18',
#  '15û_',
#  '160',
#  '16000',
#  '161116',
#  '163',
#  '164',
#  '165å',
#  '1665',
#  '16950',
#  '16yearold',
#  '16yr',
#  '1700',
#  '17000',
#  '1711',
#  '1716',
#  '178kakapo',
#  '180046587332',
#  '1800_injured',
#  '1800w',
#  '1860',
#  '18w',
#  '19000',
#  '1915',
#  '1915ûókaiserjaegers',
#  '1915ûókill',
#  '1922',
#  '1941',
#  '1944',
#  '1945',
#  '1946httpstcobojcx32qcz',
#  '1950',
#  '1954',
#  '1961',
#  '1965',
#  '1976',
#  '1980',
#  '1980s',
#  '1987',
#  '1993',
#  '19yrs',
#  '1am',
#  '1oak',
#  '1outside',
#  '1st',
#  '1ìâå',
#  '1ûòdonûªt',
#  '200',
#  '2000',
#  '20000',
#  '200000',
#  '20000k',
#  '2000s',
#  '2001',
#  '2002',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012shells',
#  '2013',
#  '2014',
#  '2015',
#  '2015ûó',
#  '2016',
#  '2029',
#  '2040',
#  '2055271',
#  '2075',
#  '2079',
#  '20k',
#  '20th',
#  '2100',
#  '212',
#  '213296',
#  '216',
#  '21day',
#  '21dayfix',
#  '21joseph',
#  '220',
#  '22lh4',
#  '22pm',
#  '2338',
#  '233liveonline',
#  '2401',
#  '241487',
#  '250',
#  '2500',
#  '250foottall',
#  '2523',
#  '25c',
#  '263chat',
#  '28lv6',
#  '29072015',
#  '295ss100',
#  '29800',
#  '2day',
#  '2disc',
#  '2gether',
#  '2in1',
#  '2k15',
#  '2nd',
#  '2night',
#  '2out',
#  '2pcs',
#  '2reduce',
#  '2x10',
#  '2ûòdonûªt',
#  '300000',
#  '30005000',
#  '300w',
#  '301',
#  '3060',
#  '320',
#  '325000',
#  '3331116',
#  '343',
#  '3581408',
#  '35w',
#  '360',
#  '360wisenews',
#  '361',
#  '367',
#  '3682',
#  '370',
#  '375',
#  '37yearold',
#  '38_degrees',
#  '390yearold',
#  '3936',
#  '3946',
#  '3acre',
#  '3alarm',
#  '3ampmy',
#  '3inspired',
#  '3match',
#  '3nach9',
#  '3pronged',
#  '3rd',
#  '3ûòdonûªt',
#  '400',
#  '4000',
#  '402',
#  '40money',
#  '40urty',
#  '411naija',
#  '4193',
#  '427',
#  '430',
#  '4353271148',
#  '435pm',
#  '446',
#  '4478427',
#  '4500feet',
#  '452',
#  '4552',
#  '462',
#  '4671416',
#  '4700',
#  '48åêhours',
#  '4get',
#  '4is',
#  '4month',
#  '4playthursdays',
#  '4pm',
#  '4wd',
#  '4x11',
#  '4x4',
#  '500',
#  '5000',
#  '500k',
#  '500û_',
#  '501',
#  '50k',
#  '50mixed',
#  '528472',
#  '530ûò730pm',
#  '535',
#  '53inch',
#  '55432',
#  '55433',
#  '55x1',
#  '581941',
#  '5km',
#  '5oilworker',
#  '5sos',
#  '5sosfam',
#  '5sosfamupdater',
#  '5sosquotes',
#  '5sostag',
#  '5sosû',
#  '5th',
#  '5û_',
#  '600',
#  '60000',
#  '60ml',
#  '61_alvin',
#  '649',
#  '64th',
#  '660news',
#  '666',
#  '666canberra',
#  '676',
#  '67676',
#  '6pm',
#  '6th',
#  '700',
#  '700am',
#  '7071',
#  '7080000',
#  '70th',
#  '715',
#  '723',
#  '72925',
#  '7294',
#  '72w',
#  '7302015',
#  '735m',
#  '750k',
#  '753',
#  '76mins',
#  '7am',
#  '7news',
#  '800',
#  '80000',
#  '80ft',
#  '80pcs',
#  '8132748811',
#  '816',
#  '818',
#  '8415',
#  '844pm',
#  '852015',
#  '8goingon80',
#  '8nn',
#  '8pm',
#  '900',
#  '9096',
#  '90blksamp8whts',
#  '90sangelicmalik',
#  '911',
#  '911åêcall',
#  '915pm',
#  '917032',
#  '930pm',
#  '9395',
#  '950',
#  '951',
#  '960kzim',
#  '97georgia',
#  '98fm',
#  '9newsmornings',
#  '9pm',
#  '9tawan99',
#  '9th',
#  '___',
#  '_afrojazz',
#  '_bomb',
#  '_drodrolagi',
#  '_gags_',
#  '_keypsters',
#  '_laladeviluke',
#  '_laneyslife',
#  '_lasha_k',
#  '_nicksimboli_',
#  '_nickwilson__',
#  '_souuul',
#  '_tonedidit',
#  'a27',
#  'a283',
#  'aa_traffic',
#  'aapatwork',
#  'aaron',
#  'aarongoodwin',
#  'aaronkearneyaus',
#  'aba',
#  'abandon',
#  'abandoned',
#  'abba',
#  'abbott',
#  'abbss_13',
#  'abbswinston',
#  'abbydphillip',
#  'abc',
#  'abc7chicago',
#  'abc7newsbayarea',
#  'abcfmelissajoey',
#  'abcnetwork',
#  'abcnews',
#  'abdulrasheed',
#  'abe',
#  'abella',
#  'abh',
#  'abide',
#  'ability',
#  'ablaze',
#  'ablaze_co',
#  'ablazeû_',
#  'able',
#  'abnormally',
#  'abolishing',
#  'abomb',
#  'abombs',
#  'abomination',
#  'aboooooortiooooonnnnns',
#  'aboriginal',
#  'aborted',
#  'abortion',
#  'abounds',
#  'aboveandbeyond',
#  'abrianna',
#  'absol',
#  'absolute',
#  'absolutely',
#  'abstorm',
#  'abt',
#  'abuse',
#  'abused',
#  'abuseddesolateamplost',
#  'academy',
#  'acapella',
#  'accept',
#  'acceptable',
#  'access',
#  'accident',
#  'accidentally',
#  'accionempresa',
#  'accomplishing',
#  'according',
#  'account',
#  'accountabilityûª',
#  'accuracyesports',
#  'accurate',
#  'accurately',
#  'accused',
#  'accuses',
#  'acdelco',
#  'ace',
#  'achieved',
#  'achievement',
#  'achimota',
#  'acid',
#  'acoustic',
#  'acquisition',
#  'acre',
#  'acreativedc',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'activate',
#  'activated',
#  'activates',
#  'activation',
#  'activist',
#  'activity',
#  'actual',
#  'actually',
#  'adam',
#  'adamrubinespn',
#  'adamtuss',
#  'adani',
#  'adapt',
#  'adarius',
#  'add',
#  'added',
#  'addictionis',
#  'adding',
#  'address',
#  'adilghumro',
#  'adjusted',
#  'adjustment',
#  'admin',
#  'administer',
#  'administration',
#  'administrator',
#  'admins',
#  'admiral',
#  'admired',
#  'admits',
#  'admitted',
#  'adolwyn',
#  'adult',
#  'adultress',
#  'advance',
#  'advanced',
#  'advancedwarfare',
#  'advantage',
#  'adventure',
#  'advice',
#  'advisory',
#  'adz77',
#  'aesthetic',
#  'affect',
#  'affected',
#  'affecting',
#  'affection',
#  'affiliate',
#  'affiliated',
#  'affluent',
#  'afford',
#  'affordable',
#  'afghan',
#  'afp',
#  'afraid',
#  'africa',
#  'african',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'aftershock',
#  'againspiritual',
#  'age',
#  'agen',
#  'agency',
#  'agent',
#  'aggravated',
#  'aggravating',
#  'aggressively',
#  'aging',
#  'ago',
#  'agree',
#  'agreed',
#  'agrees',
#  'agricultural',
#  'aguero',
#  'ahead',
#  'ahhhh',
#  'ahrar',
#  'aichi',
#  'aichmomanic',
#  'aid',
#  'aiden',
#  'aim',
#  'aint',
#  'air',
#  'airbase',
#  'airborne',
#  'aircraft',
#  'airdrie',
#  'airline',
#  'airplane',
#  'airplaneåê29072015',
#  'airport',
#  'airportwatch',
#  'airsoft',
#  'aisle',
#  'ajenews',
#  'ajmal',
#  'aka',
#  'akfnejf',
#  'akinwunmiambode',
#  'al_thegoon',
#  'ala',
#  'alabama',
#  'aladdin',
#  'alan',
#  'alarm',
#  'alarming',
#  'alaska',
#  'albania',
#  'albert',
#  'alberta',
#  'albertans',
#  'albertbreer',
#  'albertbrooks',
#  'albertville',
#  'album',
#  'alc',
#  'alcohol',
#  'alcoholismaddiction',
#  'aldwark',
#  'alejandro',
#  'aleppo',
#  'alert',
#  'alertness',
#  'aleshabell',
#  'alex',
#  'alex_the_murder',
#  'alexandbondarev',
#  'alexander',
#  'alexeeles',
#  'alexhern',
#  'alexxpage',
#  'alfa',
#  'alfons',
#  'alfred00dle',
#  'alfredo',
#  'algae',
#  'alibaba',
#  'alienateplays',
#  'alive',
#  'aliyeskii',
#  'aliyu',
#  'aljavieera',
#  'allah',
#  'allahgodjesusthe',
#  'allahuakbar',
#  'allegation',
#  'allegedly',
#  'allen',
#  'allenpeacock',
#  'allergan',
#  'alley',
#  'alliance',
#  'allied',
#  'alloutash23_sn',
#  'allow',
#  'allows',
#  'alloy',
#  'alltheway80s',
#  'allwe',
#  'ally',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'alp',
#  'alpha',
#  'alpine',
#  'alqaryatayn',
#  'alrasyid448iturasya',
#  'already',
#  'alredy',
#  'alright',
#  'also',
#  'altamonte',
#  'altered',
#  'alternate',
#  'alternative',
#  'alternativesûócategoricallyûówere',
#  'although',
#  'altitude',
#  'always',
#  'alwaysaho',
#  'alwx',
#  'alynacarol',
#  'alyssaspencer28',
#  'amaas',
#  'amanda',
#  'amandagiroux28',
#  'amase',
#  'amazing',
#  'amazingracecanada',
#  'amazingsept',
#  'amazon',
#  'ambi',
#  'ambition',
#  'ambulance',
#  'amcx',
#  'amen',
#  'amends',
#  'america',
#  'american',
#  'americanjewry',
#  'americaûªs',
#  'amerikkka',
#  'amid',
#  'amidst',
#  'amiestager',
#  'among',
#  'amp',
#  'ampamp',
#  'ampautomated',
#  'amphave',
#  'amplifier',
#  'ampveterans',
#  'amsterdam',
#  'amtrak',
#  'amusicvideoaday',
#  'amwriting',
#  'amyramponi',
#  'amyschumer',
#  'an_opus',
#  'anacrusis',
#  'anaheim',
#  'anakasparian',
#  'analogy',
#  'analysis',
#  'anatomic',
#  'anchorage',
#  'ancient',
#  'andals',
#  'andreajmarkley',
#  'andreas',
#  'android',
#  'andy',
#  'andåêword',
#  'andû_',
#  'angel',
#  'angeles',
#  'angelriveralibû_',
#  'anger',
#  'angry',
#  'angstattack',
#  'animal',
#  'animalrescue',
#  'animated',
#  'anime',
#  'aniston',
#  'ankle',
#  'annaesterly',
#  'anncoulter',
#  'annihilated',
#  'annihilation',
#  'anniv',
#  'anniversary',
#  'announcement',
#  'annoy',
#  'anoderdid',
#  'anomaly',
#  'anonymousû_',
#  'another',
#  'anq',
#  'answer',
#  'ant',
#  'antebellum',
#  'anterior',
#  'anthony',
#  'anthonyshead',
#  'anthrax',
#  'anti',
#  'antiblight',
#  'anticipate',
#  'antifracking',
#  'antioch',
#  'antiterrorism',
#  'antivirus',
#  'antonio',
#  'anxiety',
#  'any1',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anythinû_',
#  'anyway',
#  'anywhere',
#  'aol',
#  'aparra210',
#  'apartheid',
#  'apartment',
#  'apartmentloan',
#  'apc',
#  'aphid',
#  'apocalypse',
#  'apocalyptic',
#  'apocalyû_',
#  'apollo',
#  'apollobrown',
#  'apology',
#  'app',
#  'appadviceû_',
#  'appalled',
#  'apparently',
#  'appeal',
#  'appealing',
#  'appear',
#  'appears',
#  'apple',
#  'applicable',
#  'applicant',
#  'applied',
#  'apply',
#  'appointment',
#  'appraisal',
#  'appreciate',
#  'approach',
#  'approaching',
#  'approachng',
#  'appropriates',
#  'approved',
#  'approves',
#  'approximately',
#  'apps',
#  'april',
#  'aqgco',
#  'aquarius',
#  'aquatic',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabic',
#  'aramis',
#  'arc',
#  'arcadia',
#  'archipelagowolves',
#  'architect',
#  'archive',
#  'area',
#  'areasû_',
#  'arent',
#  'areû_',
#  'argentina',
#  'argument',
#  'ari',
#  'arianagrande',
#  'arizona',
#  'arm',
#  'armageddon',
#  'armed',
#  'armory',
#  'armstrong',
#  'army',
#  'arnejungjohann',
#  'arnhem',
#  'around',
#  'arrest',
#  'arrested',
#  'arrive',
#  'arrived',
#  'arriving',
#  'arsenal',
#  'arson',
#  'arsonist',
#  'art',
#  'artful',
#  'arthritis',
#  'article',
#  'artifact',
#  'artillery',
#  'artist',
#  'artwork',
#  'artû_',
#  'arvindkejriwal',
#  'as10012',
#  'asad',
#  'asap',
#  'asda',
#  'asgharchohan86',
#  'ash',
#  'ashens',
#  'asher',
#  'ashleydniece',
#  'ashniggas',
#  'ashton',
#  'ashwilliams1',
#  'ashwo',
#  'asia',
#  'asian',
#  'asics',
#  'asir',
#  'ask',
#  'askceeps',
#  'askconnor',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'asolidrighthook',
#  'aspect',
#  'assad',
#  'assault',
#  'assemble',
#  'assembly',
#  'asshole',
#  'assist',
#  'assistance',
#  'assisted',
#  'associated',
#  'association',
#  'assume',
#  'asteroid',
#  'asthma',
#  'astolfialessio',
#  'asx100',
#  'asylum',
#  'asylumû_',
#  'ate',
#  'atgames',
#  'atk',
#  'atlantic',
#  'atlasobscura',
#  'atleast',
#  'atlwtmgc',
#  'atm',
#  'atmosphere',
#  'atmospheric',
#  'atom',
#  'atomic',
#  'atop',
#  'atpworldtour',
#  'attack',
#  'attacked',
#  'attacker',
#  'attempt',
#  'attempting',
#  'attend',
#  'attendance',
#  'attendee',
#  'attending',
#  'attention',
#  'attila',
#  'attitude',
#  'attorney',
#  'atw',
#  'atxsmtx',
#  'aubreys',
#  'auburn',
#  'auckland',
#  'aucklnd',
#  'auction',
#  'audi',
#  'audio',
#  'audiobook',
#  'auditiontime',
#  'auditory',
#  'aug',
#  'aug06first',
#  'august',
#  'aunft',
#  'aunt',
#  'aurora',
#  'auspol',
#  'aussie',
#  'australia',
#  'australian',
#  'australiaûªs',
#  'auth',
#  'author',
#  'authoritarian',
#  'authority',
#  'autistic',
#  'auto',
#  'autoaccidents',
#  'autobiography',
#  'autocracy',
#  'automatic',
#  'automation',
#  'automechanics',
#  'autopsy',
#  'autumn',
#  'available',
#  'avalanche',
#  'avalon',
#  'avast',
#  'ave',
#  'averted',
#  'avery',
#  'averywelch23',
#  'avi',
#  'aviation',
#  'avocado',
#  'avoid',
#  'avoided',
#  'avoiding',
#  'avril',
#  'awaken',
#  'awakened',
#  'awakening',
#  'award',
#  'aware',
#  'away',
#  'awe',
#  'awesome',
#  'awesomejobsiri',
#  'awful',
#  'awg',
#  'awh',
#  'awhile',
#  'axegressor',
#  'axle',
#  'axwave',
#  'aya',
#  'ayatollah',
#  'azcardinals',
#  'azeroth',
#  'azz',
#  'aû_',
#  'b30wu1f2',
#  'baano',
#  'baba',
#  'babe',
#  'baby',
#  'babypicturethis',
#  'back',
#  'background',
#  'backpack',
#  'backroad',
#  'backtracking',
#  'backwards',
#  'bacon',
#  'bacup',
#  'bad',
#  'badass',
#  'badcredit',
#  'baddiemoneysign',
#  'badge',
#  'badgeofhonour',
#  'badging',
#  'badly',
#  'baeffee',
#  'bag',
#  'baggage',
#  'bagging',
#  'bail',
#  'bailout',
#  'bake',
#  'bakeofffriends',
#  'balance',
#  'balcony',
#  'bald',
#  'ball',
#  'ballad',
#  'ballina',
#  'balloon',
#  'baltimore',
#  'bamagaga',
#  'ban',
#  'banana',
#  'bananalivesmatter',
#  'band',
#  'banerjee',
#  'bang',
#  'banging',
#  'banished',
#  'banjo',
#  'bank',
#  'banki',
#  'bankruptcy',
#  'bankstown',
#  'banned',
#  'bar',
#  'barack',
#  'barackobama',
#  'barbarism',
#  'barely',
#  'bargain',
#  'barn',
#  ...]

# %%
from sklearn import svm

svm = svm.SVC(C=100)
svm.fit(X_train, y_train)
# Out:
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
from sklearn.metrics import confusion_matrix
# X_test = vectorizer.transform(X_test)
y_pred = svm.predict(X_test)

# df = pd.DataFrame()
# df["id"] = test_data["id"]
# df["target"] = y_pred
# df.to_csv("svm.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-3598cb1df5ae> in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2 # X_test = vectorizer.transform(X_test)
# ----> 3 y_pred = svm.predict(X_test)
#       4
#       5 # df = pd.DataFrame()
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     592             y = np.argmax(self.decision_function(X), axis=1)
#     593         else:
# --> 594             y = super().predict(X)
#     595         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     596
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     313         y_pred : array, shape (n_samples,)
#     314         """
# --> 315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
#     317         return predict(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\_base.py in _validate_for_predict(self, X)
#     465             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     466                              "the number of features at training time" %
# --> 467                              (n_features, self.shape_fit_[1]))
#     468         return X
#     469
#
# ValueError: X.shape[1] = 11547 should be equal to 20858, the number of features at training time

# %%
# Out:
# <7613x20858 sparse matrix of type '<class 'numpy.float64'>'
# 	with 70885 stored elements in Compressed Sparse Row format>
